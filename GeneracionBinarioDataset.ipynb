# %% [markdown]
# # Preparación del entorno de trabajo

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
FILE_PATH = "/gdrive/My Drive/Colab Notebooks/Master/Vision por Computador/Practica 1/resized_60x80/" #Guillermo
#FILE_PATH = "" #Antonio

# %% [markdown]
# # Imports

# %%
import glob
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# # Carga de los datos

# %%
def load_dataset(path):
    cont = 0
    X = []

    for img in glob.glob(path + '*.png'):
        if cont % 100 == 0:
            print(str(cont) + ' imagenes cargadas')
        cont = cont + 1

        X.append(plt.imread(img).astype('float32'))

    return np.array(X)

# %%
X = load_dataset(FILE_PATH)
# Out:
# 0 imagenes cargadas
# 100 imagenes cargadas
# 200 imagenes cargadas
# 300 imagenes cargadas
# 400 imagenes cargadas
# 500 imagenes cargadas
# 600 imagenes cargadas
# 700 imagenes cargadas
# 800 imagenes cargadas
# 900 imagenes cargadas
# 1000 imagenes cargadas
# 1100 imagenes cargadas
# 1200 imagenes cargadas
# 1300 imagenes cargadas
# 1400 imagenes cargadas
# 1500 imagenes cargadas
# 1600 imagenes cargadas
# 1700 imagenes cargadas
# 1800 imagenes cargadas
# 1900 imagenes cargadas
# 2000 imagenes cargadas
# 2100 imagenes cargadas
# 2200 imagenes cargadas
# 2300 imagenes cargadas
# 2400 imagenes cargadas
# 2500 imagenes cargadas
# 2600 imagenes cargadas
# 2700 imagenes cargadas
# 2800 imagenes cargadas
# 2900 imagenes cargadas
# 3000 imagenes cargadas
# 3100 imagenes cargadas
# 3200 imagenes cargadas
# 3300 imagenes cargadas
# 3400 imagenes cargadas
# 3500 imagenes cargadas
# 3600 imagenes cargadas
# 3700 imagenes cargadas
# 3800 imagenes cargadas
# 3900 imagenes cargadas
# ...

# %%
X.shape

# %%
with open('binary_60x80.pkl', 'wb') as file:
    pickle.dump(X, file)

# %%
# !mv '/content/binary_60x80.pkl' '/gdrive/My Drive/Colab Notebooks/Master/Vision por Computador/Practica 1/binary_60x80.pkl'
